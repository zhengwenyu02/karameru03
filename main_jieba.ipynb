# %% [markdown]
# # 结巴分词实践

# %% [markdown]
# ## 结巴分词的三种模式

# %%
# 单元格3 (全模式)
import jieba

# 全模式：cut_all=True
seg_list = jieba.cut("我来到北京清华大学", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\zhy\AppData\Local\Temp\jieba.cache
# Loading model cost 1.495 seconds.
# Prefix dict has been built successfully.
# Full Mode: 我/ 来到/ 北京/ 清华/ 清华大学/ 华大/ 大学

# %%
# 单元格4 (精确模式)
# 精确模式：cut_all=False (默认就是False，可以不写，写了更清晰)
seg_list = jieba.cut("我来到北京清华大学", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))
# Out:
# Default Mode: 我/ 来到/ 北京/ 清华大学

# %%
# 单元格5 (搜索引擎模式)
# 搜索引擎模式：使用 cut_for_search 方法
seg_list = jieba.cut_for_search("小明硕士毕业于中国科学院计算所，后在日本京都大学深造")
print("Search Mode: " + "/ ".join(seg_list))
# Out:
# Search Mode: 小明/ 硕士/ 毕业/ 于/ 中国/ 科学/ 学院/ 科学院/ 中国科学院/ 计算/ 计算所/ ，/ 后/ 在/ 日本/ 京都/ 大学/ 日本京都大学/ 深造

# %% [markdown]
# ## 载入词典

# %%
# 单元格7
# 载入自定义词典
jieba.load_userdict("userdict.txt")

# 替换成你的名字，确保 HMM=False
seg_list = jieba.cut("郑焕裕即将是自然语言处理方面的高手", cut_all=False, HMM=False)
print("载入词典后: " + "/ ".join(seg_list))
# Out:
# 载入词典后: 郑焕裕/ 即将/ 是/ 自然语言/ 处理/ 方面/ 的/ 高手
